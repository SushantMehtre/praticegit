# %%
#importing dataset
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from  warnings import filterwarnings
filterwarnings(action='ignore')

# %%
data = pd.read_csv("cancer (1).csv")
print("sucessfully import data")
data.head()
# Out:
# sucessfully import data
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.shape
# Out:
# (569, 33)

# %%
data.describe(include='all')
# Out:
#                   id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count   5.690000e+02       569   569.000000    569.000000      569.000000
# unique           NaN         2          NaN           NaN             NaN
# top              NaN         B          NaN           NaN             NaN
# freq             NaN       357          NaN           NaN             NaN
# mean    3.037183e+07       NaN    14.127292     19.289649       91.969033
# std     1.250206e+08       NaN     3.524049      4.301036       24.298981
# min     8.670000e+03       NaN     6.981000      9.710000       43.790000
# 25%     8.692180e+05       NaN    11.700000     16.170000       75.170000
# 50%     9.060240e+05       NaN    13.370000     18.840000       86.240000
# 75%     8.813129e+06       NaN    15.780000     21.800000      104.100000
# max     9.113205e+08       NaN    28.110000     39.280000      188.500000
#
#           area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
print(data.isna().sum())
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
data.corr()
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
data['Outcome'].value_count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Anaconda1\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File d:\Anaconda1\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File d:\Anaconda1\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Outcome'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.figure(figsize=(10,10))
sns.countplot(data = data,x= 'id')
plt.show()

# %%
print(data.isna().sum())
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
sns.distplot(data['diagnosis'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.distplot(data['diagnosis'])
#
# File d:\Anaconda1\lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2455     a = x
#    2457 # Make a a 1-d float array
# -> 2458 a = np.asarray(a, float)
#    2459 if a.ndim > 1:
#    2460     a = a.squeeze()
#
# File d:\Anaconda1\lib\site-packages\pandas\core\series.py:893, in Series.__array__(self, dtype)
#     846 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     847     """
#     848     Return the values as a NumPy array.
#     849
#    (...)
#     891           dtype='datetime64[ns]')
#     892     """
# --> 893     return np.asarray(self._values, dtype)
#
# ...

# %%
data.plot(kind ='box',subplots = True, layout =(4,4),sharex = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data.plot(kind ='box',subplots = True, layout =(4,4),sharex = False)
#
# File d:\Anaconda1\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File d:\Anaconda1\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File d:\Anaconda1\lib\site-packages\pandas\plotting\_matplotlib\core.py:451, in MPLPlot.generate(self)
# ...

# %%
data.hist(figsize=(15,15),bins=50)
plt.show()

# %%
corr = data.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# DATA ANALYSIS
